# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# Machine Learning
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Machine learning is the subset of Artificial intelligence that performs specific tasks by identifying patterns within data and extracting inferences.
# </li><br>
#
# <li>
# The inferences that are derived from data are then used to predict outcomes on unseen data.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![AIvsMLvsDL.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# Machine Learning vs Traditional Programming Approach
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# In classic programming, we feed in the data and some hardcoded rules and then get our required ouput.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# However, in machine learning, the rules and heuristics are not explicitly written.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# This paradigm shift differs from traditional programming where applications
# are built using well-defined rules.
# </li><br>
#
# <li>
# In ML-powered applications, the model learns to recognize patterns and create rules from the training data; it then uses these rules to make predictions on new data.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# Dataset
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# The machine learning model are learned the above rules by using a dataset.
# </li><br>
#
# <li>
# The dataset is called training dataset.
# </li><br>
#
# <li>
# The process of learning and inferring is called training.
# </li><br>
#
# <li>
# The following is an example of the famous IRIS dataset (https://archive.ics.uci.edu/ml/datasets/Iris).
# </li><br>
#
# <li>
# This dataset is a representation of different species of iris flowers based on different characteristics, such as the length and width of their sepals and petals:
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# Top Career Paths or Jobs in AI/Machine Learning
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Artificial Intelligence/Machine Learning Engineer
# </li><br>
#
# <li>
# Data Scientist
# </li><br>
#
# <li>
# Natural Language Processing Scientist
# </li><br>
#
# <li>
# Natural Language Processing Engineer
# </li><br>
#
# <li>
# Natural Language Processing Developer
# </li><br>
#
# <li>
# Business Intelligence Developer
# </li><br>
#
# <li>
# Machine Learrning Research Scientist
# </li><br>
#
# <li>
# Machine Learning Developer
# </li><br>
#
# <li>
# Data Engineer
# </li><br>
#
# <li>
# Business Intelligence Analyst
# </li><br>
#
# <li>
# Computer Vision Engineer
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![App in ML-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![App in ML-12.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <h1>
# <uL>
# <font color = 'brown red' size = '4'>
# <li>
# <b>
# The different tasks which Machine Learning has completed in real world are as under:
#
# <uL>
# <font color = 'brown red' size = '4'>
#
# <li>Email filters</li><br>
# <li>Smart assistants</li><br>
# <li>Search results</li><br>
# <li>Predictive text</li><br>
# <li>Language translation</li><br>
# <li>Digital phone calls</li><br>
# <li>Data analysis</li><br>
# <li>Text analytics</li><br>
# <li>Optical character recognition (OCR)</li><br>
# <li>Machine inspection</li><br>
# <li>Retail (e.g. automated checkouts)</li><br>
# <li>3D model building (photogrammetry)</li><br>
# <li>Medical imaging</li><br>
# <li>Automotive safety</li><br>
# <li>Match move (e.g. merging CGI with live actors in movies)</li><br>
# <li>Motion capture (mocap)</li><br>
# <li>Surveillance</li><br>
# <li>Fingerprint recognition and biometrics</li><br>
# <li>Object Classification: What broad category of object is in the photograph?</li><br>
# <li>Object Identification: Which type of a given object is in this photograph?</li><br>
# <li>Object Verification: Is the object in the photograph?</li><br>
# <li>Object Detection: Where are the objects in the photograph?</li><br>
# <li>Object Landmark Detection: What are the key points for the object in the photograph?</li><br>
# <li>Object Segmentation: What pixels belong to the object in the image?</li><br>
# <li>Object Recognition: What objects are in this photograph and where are they?</li>
# </font>
# </ul>
#
#
# </b>
# </li>
# </font>
# </ul>
