# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# Python Packages and Modules
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Python is one of the most popular programming languages used for machine learning, and is the language used here.
# </li><br>
#
# <li>
# While the standard features that are included in Python are certainly feature-rich, the true power of Python lies in the additional libraries (also known as packages).
# </li><br>
#
# <li>
# Thanks to these open source licensing packages or libraries, which can be easily downloaded and installed through a few simple commands and then we can use to develop machine learning models easily.
# </li><br>
#
# <li>
# In this course, we will be using the following additional Python packages:
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 1. NumPy
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# NumPy (pronounced Num Pie and available at https://numpy.org/.
# </li><br>
#
# <li>
# NumPy (short for numerical Python) is one of the core components of scientific computing in Python.
# </li><br>
#
# <li>
# NumPy provides the foundational data types from which a number of other data structures derive, including linear algebra, vectors and matrices, and key
# random number functionality.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![Uses-of-NumPy-1.webp](data:image/webp;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 2. SciPy
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Pronounced Sigh Pie and available at https://scipy.org/:
# </li><br>
#
# <li>
# SciPy, along with NumPy, is a core scientific computing package.
# </li><br>
#
# <li>
# SciPy provides a number of statistical tools, signal processing tools, and other functionality, such as Fourier transforms.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 3. Pandas
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Pandas is a high-performance library for loading, cleaning, analyzing, and manipulating data structures available at https://pandas.pydata.org/.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 4. Matplotlib
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Matplotlib is the foundational Python library for creating graphs and plots of datasets and is also the base package from which other Python plotting libraries derive available at https://matplotlib.org/.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 5. Seaborn
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Seaborn is a plotting library built on top of Matplotlib, providing attractive color and line styles as well as a number of common plotting templates available at https://seaborn.pydata.org/.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1><font color = 'green' size = '6'>
# <b>
# 6. Scikit-learn
# </b>
# </font>
# </h1>

# %% [markdown]
# <h1>
#
# <ul>
# <font color = 'brown red' size = '4'>
# <b>
#
# <li>
# Scikit-learn is a Python machine learning library that provides a number of data mining, modeling, and analysis techniques in a simple API.
# </li><br>
#
# <li>
# Scikit-learn includes a number of machine learning algorithms out of the box, including classification, regression, and clustering techniques available at https://scikit-learn.org/.
# </li>
#
# </ul>
# </b>
# </font>
# </ul>
# </h1>

# %% [markdown]
# ![ml_map.jpg](data:image/jpeg;base64,...)
